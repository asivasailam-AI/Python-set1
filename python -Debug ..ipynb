# %%
#1.Find the error in the following Python code:

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = 5
print(a + b)
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

def add_numbers(a, b):
    return (a + b)

# %%
#4.Identify the bug in the following Python code:

numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %% [markdown]
# # Assistant
# The error occurs because there's an unexpected indentation in your code. In Python, indentation is significant and used to define code blocks. In this case, the `print` statement is indented when it shouldn't be.
#
# Would you like me to provide the corrected code?

# %%
#5.Find the error in the following Python code:
print ("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 1

# %%
#7.Find the error in the following Python code:name = "Alice"
name = "Alice"
age = 25

print("Name: " + name + ", Age: " + str(age))
#cannot add integer with string
# Out:
# Name: Alice, Age: 25

# %%
#8.Find the error
for i in range(10, 1, -1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
#9. Find the error in the following Python code:
x = 10
if x == 5:
    print("x is 5")

# %%
#10. Identify the error in the following function definition:

def greet(name):
    print("Hello, " + name)
